# %% [markdown]
# # CSE527 Homework 4
# **Due date: 11:59 pm EST on Nov. 1, 2022 (Tue.)**
#
# In this semester, we will use Google Colab for the assignments, which allows us to utilize resources that some of us might not have in their local machines such as GPUs. You will need to use your Stony Brook (*.stonybrook.edu) account for coding and Google Drive to save your results.
#
# ## Google Colab Tutorial
# ---
# Go to https://colab.research.google.com/notebooks/, you will see a tutorial named "Welcome to Colaboratory" file, where you can learn the basics of using google colab.
#
# Settings used for assignments: ***Edit -> Notebook Settings -> Runtime Type (Python 3)***.
#
#
# ## Description
# ---
# This project is an introduction to deep learning tools for computer vision. You will design and train deep convolutional networks for scene recognition using [PyTorch](http://pytorch.org). You can visualize the
# structure of the network with [mNeuron] (http://vision03.csail.mit.edu/cnn_art/index.html)
#
# In Problem 1 of the project you will train a deep convolutional network from scratch to recognize scenes. The starter codes gives you methods to load data and display them. You will need to define a simple network architecture and add jittering, normalization, and regularization to increase recognition accuracy to 50, 60, or perhaps 70%. Unfortunately, we only have 2,400 training examples so it doesn't seem possible to train a network from scratch which outperforms hand-crafted features
#
# For Problem 2 you will instead fine-tune a pre-trained deep network to achieve about 85% accuracy on the task. We will use the pretrained AlexNet network which was not trained to recognize scenes at all.
#
# These two approaches represent the most common approaches to recognition problems in computer vision today -- train a deep network from scratch if you have enough data (it's not always obvious whether or not you do), and if you cannot then instead fine-tune a pre-trained network.
#
# There are 2 problems in this homework with a total of 120 points including 20 bonus points. Be sure to read **Submission Guidelines** below. They are important. For the problems requiring text descriptions, you might want to add a markdown block for that.
#
# ## Dataset
# ---
# Save the [dataset(click me)](https://drive.google.com/open?id=1NWC3TMsXSWN2TeoYMCjhf2N1b-WRDh-M) into your working folder in your Google Drive for this homework. <br>
# Under your root folder, there should be a folder named "data" (i.e. XXX/Surname_Givenname_SBUID/data) containing the images.
#
# ## Some Tutorials (PyTorch)
# ---
# - You will be using PyTorch for deep learning toolbox (follow the [link](http://pytorch.org) for installation).
# - For PyTorch beginners, please read this [tutorial](http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) before doing your homework.
# - Feel free to study more tutorials at http://pytorch.org/tutorials/.
# - Find cool visualization here at http://playground.tensorflow.org.

# %%
# import packages here
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import random 
import time

import torch
import torchvision
import torchvision.transforms as transforms

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

# %%
# Mount your google drive where you've saved your assignment folder
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Replace '------' with the path such that "Surname_Givenname_SBUID_hw*" is your working directory
# %cd '/content/gdrive/MyDrive/ICV/Assignment 4/Dhami_Jainam_115060058_hw4'
# Out:
# /content/gdrive/MyDrive/ICV/Assignment 4/Dhami_Jainam_115060058_hw4

# %% [markdown]
# ## Problem 0: Loading and Preprocessing data
# ---
# (0 point) In this part, you are provided with a function that loads data into minibatches for training and testing in PyTorch. However, some preprocessing parts are missing. Your will need to implement them when doing Problem 1.

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------

def set_random_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     random.seed(seed)
     torch.backends.cudnn.deterministic = True
set_random_seed(0)

class_names = [name[13:] for name in glob.glob('./data/train/*')]
class_names = dict(zip(range(len(class_names)), class_names))
print("class_names: %s " % class_names)

def load_dataset(path, img_size, num_per_class=-1, batch_size=16, shuffle=False,
           augment=False, is_color=False, zero_centered=False):    
    data = []
    labels = []    
    channel_num = 3 if is_color else 1
        
    # read images and resizing
    for id, class_name in class_names.items():
        print("Loading images from class: %s" % id)
        img_path_class = glob.glob(path + class_name + '/*.jpg')
        if num_per_class > 0:
            img_path_class = img_path_class[:num_per_class]
        labels.extend([id]*len(img_path_class))
        for filename in img_path_class:
            if is_color:
                img = cv2.imread(filename)
            else:
                img = cv2.imread(filename, 0)
            
            # resize the image
            img = cv2.resize(img, img_size, cv2.INTER_LINEAR)
            
            if is_color:
                img = np.transpose(img, [2, 0, 1])
            
            # norm pixel values to [-1, 1]
            data.append(img.astype(np.float)/255*2-1)
            
    ##########--WRITE YOUR CODE HERE--##########
    # Data Augmentation 
    if augment: 
      data.extend([cv2.flip(image, 1) for image in data])
      labels.extend(labels)




    ##########-------END OF CODE-------##########    
    
    ##########--WRITE YOUR CODE HERE--##########
    # Data Normalization
    if zero_centered:
        for i in range(len(data)):
          mean, std = cv2.meanStdDev(data[i])
          data[i] = (data[i] - mean)

        
    ##########-------END OF CODE-------##########
         
    # randomly permute (this step is important for training)
    if shuffle:
        bundle = list(zip(data, labels))
        random.shuffle(bundle)
        data, labels = zip(*bundle)
    
    # divide data into minibatches of TorchTensors
    if batch_size > 1:
        batch_data = []
        batch_labels = []
         
        for i in range(int(len(data) / batch_size)):
            minibatch_d = data[i*batch_size: (i+1)*batch_size]
            minibatch_d = np.reshape(minibatch_d, (batch_size, channel_num, img_size[0], img_size[1]))
            batch_data.append(torch.from_numpy(minibatch_d))

            minibatch_l = labels[i*batch_size: (i+1)*batch_size]
            batch_labels.append(torch.LongTensor(minibatch_l))
        data, labels = batch_data, batch_labels 
    
    return zip(batch_data, batch_labels)
# Out:
# class_names: {0: 'Forest', 1: 'Highway', 2: 'Bedroom', 3: 'Office', 4: 'Flower', 5: 'Coast', 6: 'Industrial', 7: 'InsideCity', 8: 'Kitchen', 9: 'Street', 10: 'Suburb', 11: 'LivingRoom', 12: 'TallBuilding', 13: 'Mountain', 14: 'Store', 15: 'OpenCountry'}

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
# show some images
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if len(npimg.shape) > 2:
        npimg = np.transpose(img, [1, 2, 0])
    plt.figure
    plt.imshow(npimg, 'gray')
    plt.show()
img, label = trainloader_small[0][0][11][0], trainloader_small[0][1][11]
label = int(np.array(label))
print(class_names[label])
imshow(img)
# Out:
# OpenCountry

# %% [markdown]
# ## Problem 1: Training a Network From Scratch
# The days of hand designed features are gone. Now we have end-to-end learning in which a highly non-linear representation is learned for our data to maximize our objective function (in this case, 16-way classification accuracy). Let's start!

# %% [markdown]
# First, let's define a sample network architecture.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(3600, 16), 
      )
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %% [markdown]
# Then, let's define model training and evaluation functions.

# %%
#--------------------------------------------------
#       Model Training Function
#--------------------------------------------------
import torch.optim as optim
import time
  
def trainModel(net, trainloader, train_option, testloader=None):  
  loss_func = nn.CrossEntropyLoss()
  lr = train_option['lr']
  epoch = train_option['epoch']
  device = train_option['device'] if 'device' in train_option.keys() else 'cpu'
  log_iter = train_option['log_iter'] if 'log_iter' in train_option.keys() else 20
  eval_epoch = 1
  
  if 'optimizer' in train_option.keys():
    optimizer = train_option['optimizer']
  else:
    optimizer = optim.Adam(net.parameters(), lr=lr)

  start_time = time.time()
  if device == 'gpu':
    net = net.cuda()
    
  iters = 0
  running_loss = 0.0
  for ep in range(epoch):
    net.train()        
    for iter, (x, y) in enumerate(trainloader):
      iters += 1
      batch_x = Variable(x).float()
      batch_y = Variable(y).long()
      if device == 'gpu':
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()

      outputs = net(batch_x)
      loss = loss_func(outputs, batch_y)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      running_loss += loss.item()
      
      time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
      if iter % log_iter == 0:
        print('Epoch:{:2d} | Iter:{:5d} | Time: {} | Train Loss: {:.4f} | Average Loss: {:.4f} '.format(ep+1, iter, time_lapse, loss.item(), running_loss/iters))
   
    if testloader is not None and ep % eval_epoch == 0:
      evalModel(net, testloader)

# %%
#--------------------------------------------------
#       Model Evaluating Function
#--------------------------------------------------
import time
  
def evalModel(net, testloader): 
  acc = 0.0
  count = 0
  start_time = time.time()
  device = 'gpu' if next(net.parameters()).is_cuda else 'cpu'
  net.eval()
  
  for iter, (x, y) in enumerate(testloader):
        count += x.shape[0]
        batch_x = Variable(x).float()
        batch_y = Variable(y).long()
        if device == 'gpu':
          batch_x = batch_x.cuda()
          batch_y = batch_y.cuda()
        outputs = net(batch_x)
        acc += torch.sum(outputs.max(1)[1]==batch_y)
        
  time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))        
  print('Accuracy: {:5f} | Time: {}'.format(acc/count,time_lapse))

# %% [markdown]
# Finally, let's start training and evaluation.

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:11 | Train Loss: 2.7703 | Average Loss: 2.7703
# Epoch: 1 | Iter:   20 | Time: 00:00:11 | Train Loss: 2.2010 | Average Loss: 2.6511
# Accuracy: 0.328125 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.7697 | Average Loss: 2.4654
# Epoch: 2 | Iter:   20 | Time: 00:00:11 | Train Loss: 1.4209 | Average Loss: 2.2476
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.3493 | Average Loss: 2.1257
# Epoch: 3 | Iter:   20 | Time: 00:00:11 | Train Loss: 1.0563 | Average Loss: 1.9805
# Accuracy: 0.460938 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.0978 | Average Loss: 1.8868
# Epoch: 4 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.8304 | Average Loss: 1.7752
# Accuracy: 0.466146 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.9125 | Average Loss: 1.6979
# Epoch: 5 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.6813 | Average Loss: 1.6070
# Accuracy: 0.481771 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.7771 | Average Loss: 1.5424
# Epoch: 6 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.5792 | Average Loss: 1.4666
# Accuracy: 0.489583 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6756 | Average Loss: 1.4118
# Epoch: 7 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.4914 | Average Loss: 1.3475
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.5947 | Average Loss: 1.3001
# Epoch: 8 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.4001 | Average Loss: 1.2447
# Accuracy: 0.484375 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.5320 | Average Loss: 1.2031
# Epoch: 9 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3169 | Average Loss: 1.1555
# Accuracy: 0.460938 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.4825 | Average Loss: 1.1192
# Epoch:10 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.2635 | Average Loss: 1.0788
# Accuracy: 0.458333 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.4059 | Average Loss: 1.0474
# Epoch:11 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.2006 | Average Loss: 1.0120
# Accuracy: 0.481771 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3646 | Average Loss: 0.9859
# Epoch:12 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1848 | Average Loss: 0.9557
# Accuracy: 0.486979 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3898 | Average Loss: 0.9337
# Epoch:13 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.2399 | Average Loss: 0.9080
# Accuracy: 0.445312 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.4792 | Average Loss: 0.8883
# Epoch:14 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.3161 | Average Loss: 0.8655
# Accuracy: 0.432292 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.3675 | Average Loss: 0.8470
# Epoch:15 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2878 | Average Loss: 0.8268
# Accuracy: 0.432292 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2329 | Average Loss: 0.8103
# Epoch:16 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1407 | Average Loss: 0.7910
# Accuracy: 0.429688 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2731 | Average Loss: 0.7756
# Epoch:17 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1409 | Average Loss: 0.7578
# Accuracy: 0.419271 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.4088 | Average Loss: 0.7433
# Epoch:18 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2034 | Average Loss: 0.7269
# Accuracy: 0.432292 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.4250 | Average Loss: 0.7140
# Epoch:19 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2966 | Average Loss: 0.6996
# Accuracy: 0.447917 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.3310 | Average Loss: 0.6880
# Epoch:20 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.3157 | Average Loss: 0.6757
# Accuracy: 0.450521 | Time: 00:00:00

# %% [markdown]
# Great! You would get around 0.45-0.50 accuracy by this very simple network. Now it's your job to beat this result.
#
# ### Problem 1.1
# (35 points) Try to boost the accuracy by doing the following steps:
#
# **Data Augmentation**: We don't have enough training data, let's augment the training data.
# If you **left-right flip (mirror) an image** of a scene, it never changes categories. A kitchen doesn't become a forest when mirrored. This isn't true in all domains — a "d" becomes a "b" when mirrored, so you can't "jitter" digit recognition training data in the same way. But we can synthetically increase our amount of training data by left-right mirroring training images during the learning process.
#
# After you implement mirroring, you should notice that your training error doesn't drop as quickly. That's actually a good thing, because it means the network isn't overfitting to the 2,400 original training images as much (because it sees 4,800 training images now, although they're not as good as 4,800 truly independent samples). Because the training and test errors fall more slowly, you may need more training epochs or you may try modifying the learning rate. You are **required** to implement mirroring as data augmentation for this part.
#
# You can try more elaborate forms of jittering -- zooming in a random amount, rotating a random amount, taking a random crop, etc. These are not required, you might want to try these in the bonus part.
#
# **Data Normalization**: The images aren't **zero-centered**. One simple trick which can help a lot is to subtract the mean from every image. It would arguably be more proper to only compute the mean from the training images (since the test/validation images should be strictly held out) but it won't make much of a difference. This part is **required**.
#
# **Network Regularization**: Add **dropout layer**. If you train your network (especially for more than the default 30 epochs) you'll see that the training error can decrease to zero while the val top1 error hovers at 40% to 50%. The network has learned weights which can perfectly recognize the training data, but those weights don't generalize to held out test data. The best regularization would be more training data but we don't have that. Instead we will use dropout regularization.
#
# What does dropout regularization do? It randomly turns off network connections at training time to fight overfitting. This prevents a unit in one layer from relying too strongly on a single unit in the previous layer. Dropout regularization can be interpreted as simultaneously training many "thinned" versions of your network. At test, all connections are restored which is analogous to taking an average prediction over all of the "thinned" networks. You can see a more complete discussion of dropout regularization in this [paper](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf).
#
# The dropout layer has only one free parameter — the dropout rate — the proportion of connections that are randomly deleted. The default of 0.5 should be fine. Insert a dropout layer between your convolutional layers. In particular, insert it directly before your last convolutional layer (and try others if that helps). Your train accuracy should decrease much more slowly. That's to be expected — you're making life much harder for the training algorithm by cutting out connections randomly. In this part, you are **required** to add dropout layer to your network.
#
# **Please give detailed descriptions of your network layout in the following format:**<br>
# Data augmentation: [descriptions]<br>
# Data normalization: [descriptions]<br>
# Layer 1: [layer_type]: [Parameters]<br>
# Layer 2: [layer_type]: [Parameters]<br>
# ...<br>
# **Then report the final accuracy on test set.**
#
# The minimum accuracy required for this section is **0.55**.

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(3600, 16), 
      )

      self.dropout = nn.Dropout(0.7)
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 30
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8750 | Average Loss: 2.8750
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.5806 | Average Loss: 2.6872
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.0850 | Average Loss: 2.5298
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.8950 | Average Loss: 2.4228
# Accuracy: 0.401042 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.8398 | Average Loss: 2.3688
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.9338 | Average Loss: 2.2748
# Epoch: 2 | Iter:   40 | Time: 00:00:00 | Train Loss: 1.5468 | Average Loss: 2.2085
# Epoch: 2 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.5379 | Average Loss: 2.1615
# Accuracy: 0.424479 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.6611 | Average Loss: 2.1357
# Epoch: 3 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.6522 | Average Loss: 2.0883
# Epoch: 3 | Iter:   40 | Time: 00:00:00 | Train Loss: 1.4178 | Average Loss: 2.0489
# Epoch: 3 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.4242 | Average Loss: 2.0145
# Accuracy: 0.473958 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3784 | Average Loss: 1.9943
# Epoch: 4 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.5814 | Average Loss: 1.9609
# Epoch: 4 | Iter:   40 | Time: 00:00:00 | Train Loss: 1.3729 | Average Loss: 1.9319
# Epoch: 4 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.2489 | Average Loss: 1.9062
# Accuracy: 0.520833 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.4139 | Average Loss: 1.8878
# Epoch: 5 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.4279 | Average Loss: 1.8595
# Epoch: 5 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.3743 | Average Loss: 1.8369
# Epoch: 5 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.1853 | Average Loss: 1.8140
# Accuracy: 0.518229 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2180 | Average Loss: 1.7983
# Epoch: 6 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.4087 | Average Loss: 1.7756
# Epoch: 6 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.3192 | Average Loss: 1.7557
# Epoch: 6 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.0556 | Average Loss: 1.7374
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.0534 | Average Loss: 1.7258
# Epoch: 7 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.2183 | Average Loss: 1.7068
# Epoch: 7 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.1623 | Average Loss: 1.6889
# Epoch: 7 | Iter:   60 | Time: 00:00:01 | Train Loss: 0.9287 | Average Loss: 1.6726
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2081 | Average Loss: 1.6617
# Epoch: 8 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.1607 | Average Loss: 1.6454
# Epoch: 8 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.0287 | Average Loss: 1.6301
# Epoch: 8 | Iter:   60 | Time: 00:00:01 | Train Loss: 0.9456 | Average Loss: 1.6157
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2172 | Average Loss: 1.6078
# Epoch: 9 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.2449 | Average Loss: 1.5940
# Epoch: 9 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.1767 | Average Loss: 1.5815
# Epoch: 9 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.8051 | Average Loss: 1.5688
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2140 | Average Loss: 1.5613
# Epoch:10 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.3202 | Average Loss: 1.5490
# Epoch:10 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.1311 | Average Loss: 1.5371
# Epoch:10 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.8101 | Average Loss: 1.5271
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1066 | Average Loss: 1.5187
# Epoch:11 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.2069 | Average Loss: 1.5078
# Epoch:11 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.8851 | Average Loss: 1.4973
# Epoch:11 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.7130 | Average Loss: 1.4874
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.0922 | Average Loss: 1.4813
# Epoch:12 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.1089 | Average Loss: 1.4716
# Epoch:12 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.0292 | Average Loss: 1.4620
# Epoch:12 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.7773 | Average Loss: 1.4533
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.9342 | Average Loss: 1.4471
# Epoch:13 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.2139 | Average Loss: 1.4383
# Epoch:13 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.8661 | Average Loss: 1.4301
# Epoch:13 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.7921 | Average Loss: 1.4221
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.0556 | Average Loss: 1.4167
# Epoch:14 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.1217 | Average Loss: 1.4081
# Epoch:14 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.0367 | Average Loss: 1.3997
# Epoch:14 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.7148 | Average Loss: 1.3921
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.9559 | Average Loss: 1.3873
# Epoch:15 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.9681 | Average Loss: 1.3797
# Epoch:15 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.8610 | Average Loss: 1.3729
# Epoch:15 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.8657 | Average Loss: 1.3657
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.9030 | Average Loss: 1.3609
# Epoch:16 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.9358 | Average Loss: 1.3543
# Epoch:16 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.8505 | Average Loss: 1.3483
# Epoch:16 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.6469 | Average Loss: 1.3425
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.8933 | Average Loss: 1.3382
# Epoch:17 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.9634 | Average Loss: 1.3317
# Epoch:17 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.8416 | Average Loss: 1.3253
# Epoch:17 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.6568 | Average Loss: 1.3193
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.8761 | Average Loss: 1.3153
# Epoch:18 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.9578 | Average Loss: 1.3083
# Epoch:18 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.8167 | Average Loss: 1.3027
# Epoch:18 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.7192 | Average Loss: 1.2973
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.8194 | Average Loss: 1.2936
# Epoch:19 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.9473 | Average Loss: 1.2882
# Epoch:19 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.8134 | Average Loss: 1.2832
# Epoch:19 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.6268 | Average Loss: 1.2783
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.8849 | Average Loss: 1.2753
# Epoch:20 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.0649 | Average Loss: 1.2705
# Epoch:20 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.6913 | Average Loss: 1.2657
# Epoch:20 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.6946 | Average Loss: 1.2608
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.9914 | Average Loss: 1.2572
# Epoch:21 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.0550 | Average Loss: 1.2529
# Epoch:21 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.8837 | Average Loss: 1.2484
# Epoch:21 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.6919 | Average Loss: 1.2440
# Accuracy: 0.617188 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6983 | Average Loss: 1.2411
# Epoch:22 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.9782 | Average Loss: 1.2365
# Epoch:22 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.7704 | Average Loss: 1.2324
# Epoch:22 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.8621 | Average Loss: 1.2282
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.9461 | Average Loss: 1.2250
# Epoch:23 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.9708 | Average Loss: 1.2208
# Epoch:23 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.7781 | Average Loss: 1.2168
# Epoch:23 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.6046 | Average Loss: 1.2129
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.1365 | Average Loss: 1.2106
# Epoch:24 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.0745 | Average Loss: 1.2068
# Epoch:24 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.9057 | Average Loss: 1.2029
# Epoch:24 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.7874 | Average Loss: 1.1999
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0187 | Average Loss: 1.1976
# Epoch:25 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.8571 | Average Loss: 1.1939
# Epoch:25 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.8713 | Average Loss: 1.1903
# Epoch:25 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.5474 | Average Loss: 1.1866
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.8721 | Average Loss: 1.1844
# Epoch:26 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.6954 | Average Loss: 1.1804
# Epoch:26 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.6056 | Average Loss: 1.1773
# Epoch:26 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.6325 | Average Loss: 1.1737
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.7516 | Average Loss: 1.1713
# Epoch:27 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.8519 | Average Loss: 1.1681
# Epoch:27 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.7947 | Average Loss: 1.1649
# Epoch:27 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.5820 | Average Loss: 1.1617
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.8256 | Average Loss: 1.1595
# Epoch:28 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.8190 | Average Loss: 1.1564
# Epoch:28 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.8472 | Average Loss: 1.1535
# Epoch:28 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.5423 | Average Loss: 1.1506
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.8579 | Average Loss: 1.1486
# Epoch:29 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.9397 | Average Loss: 1.1455
# Epoch:29 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.8486 | Average Loss: 1.1429
# Epoch:29 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.6858 | Average Loss: 1.1400
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.7737 | Average Loss: 1.1382
# Epoch:30 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.8362 | Average Loss: 1.1351
# Epoch:30 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.6037 | Average Loss: 1.1325
# Epoch:30 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.6541 | Average Loss: 1.1298
# Accuracy: 0.622396 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Data augmentation: The augment parameter in the load_dataset function is set to True. I have flipped the image horizontally to create a mirror image.
#
# Data normalization: I calculated the mean and subtracted it with the image data to make them zero centerd.
#
# Layer 1: [Convolution Layer] I  have 16 output channels in the Convolution Layer with kernal size = 3. I have used ReLU activation function and later applied max pooling.
#
# Layer 2: [ReLu] Activation Function Layer
#
# Layer 3: [Max Pooling Layer] Kernal Size is 4 and stride is 4
#
# Layer 4: [Dropout Layer] I have used dropout of 0.7
#
# Layer 5: [Linear Layer] In Neural Network layer, I have used 3600 input nodes and 16 output nodes
#
# Accuray on test set: 62.2396 (Best Accuracy is at epoch 29 ie 63.2812)

# %% [markdown]
# ## Problem 1.2
#
# (15 points) Try **three different techniques** taught in the class to increase the accuracy of your model. Such as increasing training data by randomly rotating training images, adding batch normalization, different activation functions (e.g., sigmoid) and model architecture modification. Note that too many layers can do you no good due to insufficient training data. Clearly describe your method and accuracy increase/decrease for each of the three techniques.
#
# The minimum accuracy required for this section is **0.60**. (At least one Technique should achieve this)
#
# ### Technique 1

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 32, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
        nn.Conv2d(32, 64, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(576, 16), 
      )

      self.dropout = nn.Dropout(0.7)
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 30
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7859 | Average Loss: 2.7859
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.7454 | Average Loss: 2.7691
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.6386 | Average Loss: 2.7322
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.4550 | Average Loss: 2.6899
# Accuracy: 0.369792 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.4214 | Average Loss: 2.6494
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.0787 | Average Loss: 2.5831
# Epoch: 2 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.0989 | Average Loss: 2.5278
# Epoch: 2 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.0768 | Average Loss: 2.4723
# Accuracy: 0.421875 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.0547 | Average Loss: 2.4349
# Epoch: 3 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.6017 | Average Loss: 2.3823
# Epoch: 3 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.8499 | Average Loss: 2.3372
# Epoch: 3 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.9398 | Average Loss: 2.2983
# Accuracy: 0.450521 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.8846 | Average Loss: 2.2690
# Epoch: 4 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.4202 | Average Loss: 2.2301
# Epoch: 4 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.7057 | Average Loss: 2.1984
# Epoch: 4 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.7234 | Average Loss: 2.1651
# Accuracy: 0.510417 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.7687 | Average Loss: 2.1431
# Epoch: 5 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.5418 | Average Loss: 2.1134
# Epoch: 5 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.7686 | Average Loss: 2.0903
# Epoch: 5 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.6695 | Average Loss: 2.0640
# Accuracy: 0.518229 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.5842 | Average Loss: 2.0462
# Epoch: 6 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.2964 | Average Loss: 2.0216
# Epoch: 6 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.6304 | Average Loss: 2.0017
# Epoch: 6 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.5252 | Average Loss: 1.9818
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.5956 | Average Loss: 1.9675
# Epoch: 7 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.3526 | Average Loss: 1.9489
# Epoch: 7 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.4171 | Average Loss: 1.9338
# Epoch: 7 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.5472 | Average Loss: 1.9171
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.5776 | Average Loss: 1.9049
# Epoch: 8 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.3183 | Average Loss: 1.8883
# Epoch: 8 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.5399 | Average Loss: 1.8752
# Epoch: 8 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.3344 | Average Loss: 1.8606
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.5546 | Average Loss: 1.8498
# Epoch: 9 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.1806 | Average Loss: 1.8370
# Epoch: 9 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.4024 | Average Loss: 1.8256
# Epoch: 9 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.5126 | Average Loss: 1.8140
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.4814 | Average Loss: 1.8047
# Epoch:10 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.2494 | Average Loss: 1.7948
# Epoch:10 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.5044 | Average Loss: 1.7851
# Epoch:10 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.4255 | Average Loss: 1.7741
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5897 | Average Loss: 1.7670
# Epoch:11 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.0985 | Average Loss: 1.7565
# Epoch:11 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.3626 | Average Loss: 1.7484
# Epoch:11 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.3118 | Average Loss: 1.7391
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.3284 | Average Loss: 1.7325
# Epoch:12 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.1346 | Average Loss: 1.7234
# Epoch:12 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.4661 | Average Loss: 1.7164
# Epoch:12 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.4865 | Average Loss: 1.7083
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.5087 | Average Loss: 1.7021
# Epoch:13 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.3342 | Average Loss: 1.6938
# Epoch:13 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.4232 | Average Loss: 1.6874
# Epoch:13 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.2897 | Average Loss: 1.6803
# Accuracy: 0.619792 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.4743 | Average Loss: 1.6750
# Epoch:14 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.0750 | Average Loss: 1.6670
# Epoch:14 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.3636 | Average Loss: 1.6611
# Epoch:14 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.3215 | Average Loss: 1.6539
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.4813 | Average Loss: 1.6480
# Epoch:15 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.0631 | Average Loss: 1.6407
# Epoch:15 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.2960 | Average Loss: 1.6355
# Epoch:15 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.5835 | Average Loss: 1.6291
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.4498 | Average Loss: 1.6246
# Epoch:16 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.0357 | Average Loss: 1.6184
# Epoch:16 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.4875 | Average Loss: 1.6139
# Epoch:16 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.1911 | Average Loss: 1.6069
# Accuracy: 0.640625 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.2690 | Average Loss: 1.6030
# Epoch:17 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.1767 | Average Loss: 1.5976
# Epoch:17 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.4126 | Average Loss: 1.5934
# Epoch:17 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.2861 | Average Loss: 1.5878
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.3426 | Average Loss: 1.5844
# Epoch:18 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.1154 | Average Loss: 1.5794
# Epoch:18 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.2847 | Average Loss: 1.5748
# Epoch:18 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.3527 | Average Loss: 1.5699
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.4594 | Average Loss: 1.5666
# Epoch:19 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.1269 | Average Loss: 1.5613
# Epoch:19 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.3560 | Average Loss: 1.5574
# Epoch:19 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.1303 | Average Loss: 1.5523
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.2924 | Average Loss: 1.5486
# Epoch:20 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.0658 | Average Loss: 1.5438
# Epoch:20 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.2545 | Average Loss: 1.5401
# Epoch:20 | Iter:   60 | Time: 00:00:07 | Train Loss: 1.3940 | Average Loss: 1.5367
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.3915 | Average Loss: 1.5339
# Epoch:21 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.9577 | Average Loss: 1.5295
# Epoch:21 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.2557 | Average Loss: 1.5258
# Epoch:21 | Iter:   60 | Time: 00:00:07 | Train Loss: 1.3659 | Average Loss: 1.5217
# Accuracy: 0.682292 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.3423 | Average Loss: 1.5184
# Epoch:22 | Iter:   20 | Time: 00:00:07 | Train Loss: 1.0267 | Average Loss: 1.5144
# Epoch:22 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.3760 | Average Loss: 1.5113
# Epoch:22 | Iter:   60 | Time: 00:00:07 | Train Loss: 1.2893 | Average Loss: 1.5070
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.4289 | Average Loss: 1.5042
# Epoch:23 | Iter:   20 | Time: 00:00:07 | Train Loss: 1.0328 | Average Loss: 1.4999
# Epoch:23 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.2214 | Average Loss: 1.4964
# Epoch:23 | Iter:   60 | Time: 00:00:08 | Train Loss: 1.0891 | Average Loss: 1.4927
# Accuracy: 0.677083 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.0074 | Average Loss: 1.4902
# Epoch:24 | Iter:   20 | Time: 00:00:08 | Train Loss: 1.0052 | Average Loss: 1.4862
# Epoch:24 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.1348 | Average Loss: 1.4834
# Epoch:24 | Iter:   60 | Time: 00:00:08 | Train Loss: 1.2643 | Average Loss: 1.4801
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.2034 | Average Loss: 1.4774
# Epoch:25 | Iter:   20 | Time: 00:00:08 | Train Loss: 1.0483 | Average Loss: 1.4735
# Epoch:25 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.2164 | Average Loss: 1.4705
# Epoch:25 | Iter:   60 | Time: 00:00:08 | Train Loss: 1.2572 | Average Loss: 1.4669
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.1503 | Average Loss: 1.4645
# Epoch:26 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.0123 | Average Loss: 1.4612
# Epoch:26 | Iter:   40 | Time: 00:00:09 | Train Loss: 1.3166 | Average Loss: 1.4585
# Epoch:26 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.3518 | Average Loss: 1.4553
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.1708 | Average Loss: 1.4528
# Epoch:27 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.9955 | Average Loss: 1.4495
# Epoch:27 | Iter:   40 | Time: 00:00:09 | Train Loss: 1.2049 | Average Loss: 1.4471
# Epoch:27 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.1421 | Average Loss: 1.4440
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.1406 | Average Loss: 1.4421
# Epoch:28 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.1569 | Average Loss: 1.4391
# Epoch:28 | Iter:   40 | Time: 00:00:09 | Train Loss: 1.3304 | Average Loss: 1.4365
# Epoch:28 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.0799 | Average Loss: 1.4334
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:10 | Train Loss: 1.2977 | Average Loss: 1.4313
# Epoch:29 | Iter:   20 | Time: 00:00:10 | Train Loss: 1.0448 | Average Loss: 1.4285
# Epoch:29 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.0773 | Average Loss: 1.4261
# Epoch:29 | Iter:   60 | Time: 00:00:10 | Train Loss: 1.3704 | Average Loss: 1.4232
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:10 | Train Loss: 1.4701 | Average Loss: 1.4211
# Epoch:30 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.9720 | Average Loss: 1.4184
# Epoch:30 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.1739 | Average Loss: 1.4164
# Epoch:30 | Iter:   60 | Time: 00:00:10 | Train Loss: 1.3387 | Average Loss: 1.4137
# Accuracy: 0.653646 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 1: Adding a convolution Layer, ReLU Activation Funtion Layer and a MaxPooling Layer
#
# Accuracy on test set: 65.3646  (Maximum Accuracy is 68.2292 at 21 epoch)
#
# Accuracy increases/decreases: Increases

# %% [markdown]
# ### Technique 2

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 32, 3),
        nn.BatchNorm2d(32),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
        nn.Conv2d(32, 64, 3),
        nn.BatchNorm2d(64),
        nn.Sigmoid(),
        nn.MaxPool2d(4, stride=4), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(576, 16), 
         nn.BatchNorm1d(16)
      )

      self.dropout = nn.Dropout(0.7)
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 40
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.1529 | Average Loss: 3.1529
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.8032 | Average Loss: 3.0163
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.7067 | Average Loss: 2.8913
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.7015 | Average Loss: 2.8190
# Accuracy: 0.291667 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.5681 | Average Loss: 2.7680
# Epoch: 2 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.5353 | Average Loss: 2.7187
# Epoch: 2 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.6283 | Average Loss: 2.6789
# Epoch: 2 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.4672 | Average Loss: 2.6356
# Accuracy: 0.372396 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.2480 | Average Loss: 2.6060
# Epoch: 3 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.2468 | Average Loss: 2.5695
# Epoch: 3 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.4038 | Average Loss: 2.5360
# Epoch: 3 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.2987 | Average Loss: 2.5054
# Accuracy: 0.484375 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.1291 | Average Loss: 2.4838
# Epoch: 4 | Iter:   20 | Time: 00:00:02 | Train Loss: 2.2834 | Average Loss: 2.4571
# Epoch: 4 | Iter:   40 | Time: 00:00:02 | Train Loss: 2.2724 | Average Loss: 2.4327
# Epoch: 4 | Iter:   60 | Time: 00:00:02 | Train Loss: 2.1831 | Average Loss: 2.4075
# Accuracy: 0.484375 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.0177 | Average Loss: 2.3886
# Epoch: 5 | Iter:   20 | Time: 00:00:02 | Train Loss: 2.1919 | Average Loss: 2.3668
# Epoch: 5 | Iter:   40 | Time: 00:00:02 | Train Loss: 2.0644 | Average Loss: 2.3455
# Epoch: 5 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.9067 | Average Loss: 2.3230
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.9070 | Average Loss: 2.3079
# Epoch: 6 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.9860 | Average Loss: 2.2910
# Epoch: 6 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.9428 | Average Loss: 2.2730
# Epoch: 6 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.8303 | Average Loss: 2.2549
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.7509 | Average Loss: 2.2407
# Epoch: 7 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.8999 | Average Loss: 2.2247
# Epoch: 7 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.8891 | Average Loss: 2.2086
# Epoch: 7 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.8312 | Average Loss: 2.1923
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.7123 | Average Loss: 2.1804
# Epoch: 8 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.9179 | Average Loss: 2.1665
# Epoch: 8 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.8902 | Average Loss: 2.1538
# Epoch: 8 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.7761 | Average Loss: 2.1391
# Accuracy: 0.617188 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.7162 | Average Loss: 2.1290
# Epoch: 9 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.7159 | Average Loss: 2.1162
# Epoch: 9 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.6406 | Average Loss: 2.1047
# Epoch: 9 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.7384 | Average Loss: 2.0924
# Accuracy: 0.640625 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.5833 | Average Loss: 2.0833
# Epoch:10 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.7021 | Average Loss: 2.0721
# Epoch:10 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.7343 | Average Loss: 2.0615
# Epoch:10 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.5659 | Average Loss: 2.0501
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.5301 | Average Loss: 2.0421
# Epoch:11 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.5977 | Average Loss: 2.0316
# Epoch:11 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.6255 | Average Loss: 2.0217
# Epoch:11 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.6710 | Average Loss: 2.0115
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.4726 | Average Loss: 2.0038
# Epoch:12 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.6511 | Average Loss: 1.9943
# Epoch:12 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.5921 | Average Loss: 1.9852
# Epoch:12 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.6097 | Average Loss: 1.9758
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.5233 | Average Loss: 1.9694
# Epoch:13 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.5713 | Average Loss: 1.9609
# Epoch:13 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.5960 | Average Loss: 1.9527
# Epoch:13 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.6165 | Average Loss: 1.9434
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.4792 | Average Loss: 1.9368
# Epoch:14 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.5675 | Average Loss: 1.9285
# Epoch:14 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.5958 | Average Loss: 1.9210
# Epoch:14 | Iter:   60 | Time: 00:00:07 | Train Loss: 1.4759 | Average Loss: 1.9131
# Accuracy: 0.640625 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.3379 | Average Loss: 1.9069
# Epoch:15 | Iter:   20 | Time: 00:00:07 | Train Loss: 1.4445 | Average Loss: 1.8995
# Epoch:15 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.5584 | Average Loss: 1.8928
# Epoch:15 | Iter:   60 | Time: 00:00:07 | Train Loss: 1.5368 | Average Loss: 1.8850
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.5009 | Average Loss: 1.8794
# Epoch:16 | Iter:   20 | Time: 00:00:07 | Train Loss: 1.4819 | Average Loss: 1.8723
# Epoch:16 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.4935 | Average Loss: 1.8661
# Epoch:16 | Iter:   60 | Time: 00:00:08 | Train Loss: 1.5418 | Average Loss: 1.8590
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.3231 | Average Loss: 1.8538
# Epoch:17 | Iter:   20 | Time: 00:00:08 | Train Loss: 1.5850 | Average Loss: 1.8473
# Epoch:17 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.4677 | Average Loss: 1.8410
# Epoch:17 | Iter:   60 | Time: 00:00:08 | Train Loss: 1.4701 | Average Loss: 1.8341
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.3568 | Average Loss: 1.8290
# Epoch:18 | Iter:   20 | Time: 00:00:08 | Train Loss: 1.5618 | Average Loss: 1.8228
# Epoch:18 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.3236 | Average Loss: 1.8166
# Epoch:18 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.4980 | Average Loss: 1.8103
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.2182 | Average Loss: 1.8056
# Epoch:19 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.3756 | Average Loss: 1.8001
# Epoch:19 | Iter:   40 | Time: 00:00:09 | Train Loss: 1.4459 | Average Loss: 1.7941
# Epoch:19 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.4482 | Average Loss: 1.7880
# Accuracy: 0.666667 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.2514 | Average Loss: 1.7838
# Epoch:20 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.3479 | Average Loss: 1.7778
# Epoch:20 | Iter:   40 | Time: 00:00:09 | Train Loss: 1.4930 | Average Loss: 1.7724
# Epoch:20 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.4604 | Average Loss: 1.7668
# Accuracy: 0.682292 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:10 | Train Loss: 1.2606 | Average Loss: 1.7626
# Epoch:21 | Iter:   20 | Time: 00:00:10 | Train Loss: 1.4730 | Average Loss: 1.7575
# Epoch:21 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.4128 | Average Loss: 1.7527
# Epoch:21 | Iter:   60 | Time: 00:00:10 | Train Loss: 1.5531 | Average Loss: 1.7476
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:10 | Train Loss: 1.3184 | Average Loss: 1.7437
# Epoch:22 | Iter:   20 | Time: 00:00:10 | Train Loss: 1.3470 | Average Loss: 1.7390
# Epoch:22 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.4198 | Average Loss: 1.7342
# Epoch:22 | Iter:   60 | Time: 00:00:10 | Train Loss: 1.5480 | Average Loss: 1.7294
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.1513 | Average Loss: 1.7258
# Epoch:23 | Iter:   20 | Time: 00:00:11 | Train Loss: 1.3953 | Average Loss: 1.7212
# Epoch:23 | Iter:   40 | Time: 00:00:11 | Train Loss: 1.3820 | Average Loss: 1.7167
# Epoch:23 | Iter:   60 | Time: 00:00:11 | Train Loss: 1.4725 | Average Loss: 1.7118
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.2595 | Average Loss: 1.7083
# Epoch:24 | Iter:   20 | Time: 00:00:11 | Train Loss: 1.2584 | Average Loss: 1.7036
# Epoch:24 | Iter:   40 | Time: 00:00:11 | Train Loss: 1.3637 | Average Loss: 1.6994
# Epoch:24 | Iter:   60 | Time: 00:00:11 | Train Loss: 1.4364 | Average Loss: 1.6944
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.1284 | Average Loss: 1.6910
# Epoch:25 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.2461 | Average Loss: 1.6867
# Epoch:25 | Iter:   40 | Time: 00:00:12 | Train Loss: 1.3857 | Average Loss: 1.6830
# Epoch:25 | Iter:   60 | Time: 00:00:12 | Train Loss: 1.4249 | Average Loss: 1.6783
# Accuracy: 0.684896 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:12 | Train Loss: 1.3190 | Average Loss: 1.6749
# Epoch:26 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.3393 | Average Loss: 1.6711
# Epoch:26 | Iter:   40 | Time: 00:00:12 | Train Loss: 1.2746 | Average Loss: 1.6673
# Epoch:26 | Iter:   60 | Time: 00:00:12 | Train Loss: 1.3409 | Average Loss: 1.6630
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:12 | Train Loss: 1.2111 | Average Loss: 1.6603
# Epoch:27 | Iter:   20 | Time: 00:00:13 | Train Loss: 1.2132 | Average Loss: 1.6562
# Epoch:27 | Iter:   40 | Time: 00:00:13 | Train Loss: 1.3465 | Average Loss: 1.6528
# Epoch:27 | Iter:   60 | Time: 00:00:13 | Train Loss: 1.2581 | Average Loss: 1.6486
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:13 | Train Loss: 1.2036 | Average Loss: 1.6458
# Epoch:28 | Iter:   20 | Time: 00:00:13 | Train Loss: 1.2932 | Average Loss: 1.6424
# Epoch:28 | Iter:   40 | Time: 00:00:13 | Train Loss: 1.3593 | Average Loss: 1.6389
# Epoch:28 | Iter:   60 | Time: 00:00:13 | Train Loss: 1.3136 | Average Loss: 1.6351
# Accuracy: 0.710938 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:13 | Train Loss: 1.1773 | Average Loss: 1.6322
# Epoch:29 | Iter:   20 | Time: 00:00:13 | Train Loss: 1.1775 | Average Loss: 1.6285
# Epoch:29 | Iter:   40 | Time: 00:00:14 | Train Loss: 1.2540 | Average Loss: 1.6249
# Epoch:29 | Iter:   60 | Time: 00:00:14 | Train Loss: 1.2698 | Average Loss: 1.6212
# Accuracy: 0.679688 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:14 | Train Loss: 1.1630 | Average Loss: 1.6185
# Epoch:30 | Iter:   20 | Time: 00:00:14 | Train Loss: 1.2811 | Average Loss: 1.6150
# Epoch:30 | Iter:   40 | Time: 00:00:14 | Train Loss: 1.1842 | Average Loss: 1.6119
# Epoch:30 | Iter:   60 | Time: 00:00:14 | Train Loss: 1.2654 | Average Loss: 1.6083
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:14 | Train Loss: 1.1959 | Average Loss: 1.6057
# Epoch:31 | Iter:   20 | Time: 00:00:14 | Train Loss: 1.1622 | Average Loss: 1.6023
# Epoch:31 | Iter:   40 | Time: 00:00:15 | Train Loss: 1.2382 | Average Loss: 1.5994
# Epoch:31 | Iter:   60 | Time: 00:00:15 | Train Loss: 1.2664 | Average Loss: 1.5958
# Accuracy: 0.682292 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:15 | Train Loss: 1.1686 | Average Loss: 1.5931
# Epoch:32 | Iter:   20 | Time: 00:00:15 | Train Loss: 1.0870 | Average Loss: 1.5899
# Epoch:32 | Iter:   40 | Time: 00:00:15 | Train Loss: 1.1660 | Average Loss: 1.5868
# Epoch:32 | Iter:   60 | Time: 00:00:15 | Train Loss: 1.3537 | Average Loss: 1.5835
# Accuracy: 0.716146 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:15 | Train Loss: 1.1075 | Average Loss: 1.5812
# Epoch:33 | Iter:   20 | Time: 00:00:15 | Train Loss: 1.1265 | Average Loss: 1.5779
# Epoch:33 | Iter:   40 | Time: 00:00:16 | Train Loss: 1.1623 | Average Loss: 1.5749
# Epoch:33 | Iter:   60 | Time: 00:00:16 | Train Loss: 1.2488 | Average Loss: 1.5718
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:16 | Train Loss: 1.0399 | Average Loss: 1.5694
# Epoch:34 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.2145 | Average Loss: 1.5664
# Epoch:34 | Iter:   40 | Time: 00:00:16 | Train Loss: 1.1524 | Average Loss: 1.5635
# Epoch:34 | Iter:   60 | Time: 00:00:16 | Train Loss: 1.1434 | Average Loss: 1.5603
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:16 | Train Loss: 1.0733 | Average Loss: 1.5581
# Epoch:35 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.1050 | Average Loss: 1.5548
# Epoch:35 | Iter:   40 | Time: 00:00:16 | Train Loss: 1.2382 | Average Loss: 1.5522
# Epoch:35 | Iter:   60 | Time: 00:00:17 | Train Loss: 1.1357 | Average Loss: 1.5490
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:17 | Train Loss: 1.0983 | Average Loss: 1.5468
# Epoch:36 | Iter:   20 | Time: 00:00:17 | Train Loss: 1.2359 | Average Loss: 1.5440
# Epoch:36 | Iter:   40 | Time: 00:00:17 | Train Loss: 1.3084 | Average Loss: 1.5413
# Epoch:36 | Iter:   60 | Time: 00:00:17 | Train Loss: 1.2413 | Average Loss: 1.5382
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:17 | Train Loss: 1.0990 | Average Loss: 1.5362
# Epoch:37 | Iter:   20 | Time: 00:00:17 | Train Loss: 1.1264 | Average Loss: 1.5333
# Epoch:37 | Iter:   40 | Time: 00:00:17 | Train Loss: 1.1248 | Average Loss: 1.5307
# Epoch:37 | Iter:   60 | Time: 00:00:18 | Train Loss: 1.1934 | Average Loss: 1.5277
# Accuracy: 0.723958 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:18 | Train Loss: 1.0815 | Average Loss: 1.5258
# Epoch:38 | Iter:   20 | Time: 00:00:18 | Train Loss: 1.1925 | Average Loss: 1.5233
# Epoch:38 | Iter:   40 | Time: 00:00:18 | Train Loss: 1.2321 | Average Loss: 1.5209
# Epoch:38 | Iter:   60 | Time: 00:00:18 | Train Loss: 1.2733 | Average Loss: 1.5180
# Accuracy: 0.723958 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:18 | Train Loss: 1.1116 | Average Loss: 1.5161
# Epoch:39 | Iter:   20 | Time: 00:00:18 | Train Loss: 1.1241 | Average Loss: 1.5134
# Epoch:39 | Iter:   40 | Time: 00:00:18 | Train Loss: 1.1322 | Average Loss: 1.5109
# Epoch:39 | Iter:   60 | Time: 00:00:18 | Train Loss: 1.2059 | Average Loss: 1.5084
# Accuracy: 0.721354 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:19 | Train Loss: 1.0842 | Average Loss: 1.5064
# Epoch:40 | Iter:   20 | Time: 00:00:19 | Train Loss: 1.2001 | Average Loss: 1.5038
# Epoch:40 | Iter:   40 | Time: 00:00:19 | Train Loss: 1.1323 | Average Loss: 1.5014
# Epoch:40 | Iter:   60 | Time: 00:00:19 | Train Loss: 1.0913 | Average Loss: 1.4987
# Accuracy: 0.710938 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 2: Adding Batch Normalization and using Sigmoid Activation Function in addition to the architecture of Technique 1
#
# Accuracy on test set: 71.0938 (Maximum Accuracy of 72.3958 at 38 epoch)
#
# Accuracy increases/decreases: Increases

# %% [markdown]
# ### Technique 3

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 32, 3),
        nn.BatchNorm2d(32),
        nn.LeakyReLU(),
        nn.MaxPool2d(4, stride=4), 
        nn.Conv2d(32, 64, 3),
        nn.BatchNorm2d(64),
        nn.Softmax(),
        nn.MaxPool2d(4, stride=4), 
        nn.Dropout(0.6)
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(576, 32), 
         nn.BatchNorm1d(32),
         nn.ReLU(),
         nn.Linear(32, 16)
      )

      self.dropout = nn.Dropout(0.7)
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 60
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:139: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8752 | Average Loss: 2.8752
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.7873 | Average Loss: 2.7736
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.5723 | Average Loss: 2.7192
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.5821 | Average Loss: 2.6708
# Accuracy: 0.239583 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.6444 | Average Loss: 2.6437
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.4908 | Average Loss: 2.6106
# Epoch: 2 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.3481 | Average Loss: 2.5774
# Epoch: 2 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.3611 | Average Loss: 2.5429
# Accuracy: 0.361979 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.4148 | Average Loss: 2.5243
# Epoch: 3 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.3153 | Average Loss: 2.4951
# Epoch: 3 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.1187 | Average Loss: 2.4675
# Epoch: 3 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.3020 | Average Loss: 2.4421
# Accuracy: 0.427083 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.4279 | Average Loss: 2.4250
# Epoch: 4 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.0432 | Average Loss: 2.4022
# Epoch: 4 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.1683 | Average Loss: 2.3828
# Epoch: 4 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.0982 | Average Loss: 2.3599
# Accuracy: 0.450521 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.1118 | Average Loss: 2.3458
# Epoch: 5 | Iter:   20 | Time: 00:00:02 | Train Loss: 2.1056 | Average Loss: 2.3260
# Epoch: 5 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.9748 | Average Loss: 2.3081
# Epoch: 5 | Iter:   60 | Time: 00:00:02 | Train Loss: 2.0471 | Average Loss: 2.2889
# Accuracy: 0.492188 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.0459 | Average Loss: 2.2774
# Epoch: 6 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.8684 | Average Loss: 2.2606
# Epoch: 6 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.9820 | Average Loss: 2.2451
# Epoch: 6 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.9680 | Average Loss: 2.2298
# Accuracy: 0.481771 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.9687 | Average Loss: 2.2197
# Epoch: 7 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.8269 | Average Loss: 2.2038
# Epoch: 7 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.6991 | Average Loss: 2.1887
# Epoch: 7 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.9357 | Average Loss: 2.1735
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.8319 | Average Loss: 2.1644
# Epoch: 8 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.9306 | Average Loss: 2.1522
# Epoch: 8 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.6442 | Average Loss: 2.1385
# Epoch: 8 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.9617 | Average Loss: 2.1256
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.8307 | Average Loss: 2.1182
# Epoch: 9 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.6640 | Average Loss: 2.1073
# Epoch: 9 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.7751 | Average Loss: 2.0948
# Epoch: 9 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.7985 | Average Loss: 2.0836
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.7638 | Average Loss: 2.0757
# Epoch:10 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.7057 | Average Loss: 2.0650
# Epoch:10 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.6676 | Average Loss: 2.0552
# Epoch:10 | Iter:   60 | Time: 00:00:04 | Train Loss: 1.5737 | Average Loss: 2.0452
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.7159 | Average Loss: 2.0393
# Epoch:11 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.7551 | Average Loss: 2.0309
# Epoch:11 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.6352 | Average Loss: 2.0212
# Epoch:11 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.6563 | Average Loss: 2.0134
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.6023 | Average Loss: 2.0075
# Epoch:12 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.6654 | Average Loss: 1.9997
# Epoch:12 | Iter:   40 | Time: 00:00:05 | Train Loss: 1.7273 | Average Loss: 1.9919
# Epoch:12 | Iter:   60 | Time: 00:00:05 | Train Loss: 1.5369 | Average Loss: 1.9838
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.7821 | Average Loss: 1.9785
# Epoch:13 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.6794 | Average Loss: 1.9712
# Epoch:13 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.7881 | Average Loss: 1.9647
# Epoch:13 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.7379 | Average Loss: 1.9570
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.6298 | Average Loss: 1.9523
# Epoch:14 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.5428 | Average Loss: 1.9449
# Epoch:14 | Iter:   40 | Time: 00:00:06 | Train Loss: 1.6172 | Average Loss: 1.9385
# Epoch:14 | Iter:   60 | Time: 00:00:06 | Train Loss: 1.7141 | Average Loss: 1.9318
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.4582 | Average Loss: 1.9278
# Epoch:15 | Iter:   20 | Time: 00:00:07 | Train Loss: 1.7571 | Average Loss: 1.9221
# Epoch:15 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.5924 | Average Loss: 1.9156
# Epoch:15 | Iter:   60 | Time: 00:00:07 | Train Loss: 1.6118 | Average Loss: 1.9098
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.7307 | Average Loss: 1.9059
# Epoch:16 | Iter:   20 | Time: 00:00:07 | Train Loss: 1.5206 | Average Loss: 1.9006
# Epoch:16 | Iter:   40 | Time: 00:00:07 | Train Loss: 1.7516 | Average Loss: 1.8953
# Epoch:16 | Iter:   60 | Time: 00:00:07 | Train Loss: 1.6039 | Average Loss: 1.8899
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.6309 | Average Loss: 1.8864
# Epoch:17 | Iter:   20 | Time: 00:00:08 | Train Loss: 1.6901 | Average Loss: 1.8811
# Epoch:17 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.5555 | Average Loss: 1.8758
# Epoch:17 | Iter:   60 | Time: 00:00:08 | Train Loss: 1.5373 | Average Loss: 1.8701
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.4203 | Average Loss: 1.8667
# Epoch:18 | Iter:   20 | Time: 00:00:08 | Train Loss: 1.5120 | Average Loss: 1.8618
# Epoch:18 | Iter:   40 | Time: 00:00:08 | Train Loss: 1.4523 | Average Loss: 1.8568
# Epoch:18 | Iter:   60 | Time: 00:00:08 | Train Loss: 1.5646 | Average Loss: 1.8523
# Accuracy: 0.619792 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:08 | Train Loss: 1.4950 | Average Loss: 1.8488
# Epoch:19 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.6596 | Average Loss: 1.8441
# Epoch:19 | Iter:   40 | Time: 00:00:09 | Train Loss: 1.5758 | Average Loss: 1.8399
# Epoch:19 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.3927 | Average Loss: 1.8361
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.4631 | Average Loss: 1.8332
# Epoch:20 | Iter:   20 | Time: 00:00:09 | Train Loss: 1.6042 | Average Loss: 1.8294
# Epoch:20 | Iter:   40 | Time: 00:00:09 | Train Loss: 1.4279 | Average Loss: 1.8247
# Epoch:20 | Iter:   60 | Time: 00:00:09 | Train Loss: 1.5298 | Average Loss: 1.8209
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.4594 | Average Loss: 1.8182
# Epoch:21 | Iter:   20 | Time: 00:00:10 | Train Loss: 1.5275 | Average Loss: 1.8148
# Epoch:21 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.5482 | Average Loss: 1.8106
# Epoch:21 | Iter:   60 | Time: 00:00:10 | Train Loss: 1.3315 | Average Loss: 1.8064
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:10 | Train Loss: 1.4549 | Average Loss: 1.8038
# Epoch:22 | Iter:   20 | Time: 00:00:10 | Train Loss: 1.5271 | Average Loss: 1.7996
# Epoch:22 | Iter:   40 | Time: 00:00:10 | Train Loss: 1.6131 | Average Loss: 1.7962
# Epoch:22 | Iter:   60 | Time: 00:00:10 | Train Loss: 1.5270 | Average Loss: 1.7927
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:10 | Train Loss: 1.5403 | Average Loss: 1.7905
# Epoch:23 | Iter:   20 | Time: 00:00:11 | Train Loss: 1.5147 | Average Loss: 1.7869
# Epoch:23 | Iter:   40 | Time: 00:00:11 | Train Loss: 1.8197 | Average Loss: 1.7833
# Epoch:23 | Iter:   60 | Time: 00:00:11 | Train Loss: 1.3897 | Average Loss: 1.7797
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.3192 | Average Loss: 1.7774
# Epoch:24 | Iter:   20 | Time: 00:00:11 | Train Loss: 1.3744 | Average Loss: 1.7743
# Epoch:24 | Iter:   40 | Time: 00:00:11 | Train Loss: 1.6453 | Average Loss: 1.7708
# Epoch:24 | Iter:   60 | Time: 00:00:11 | Train Loss: 1.4468 | Average Loss: 1.7673
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.4965 | Average Loss: 1.7650
# Epoch:25 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.4173 | Average Loss: 1.7616
# Epoch:25 | Iter:   40 | Time: 00:00:12 | Train Loss: 1.5099 | Average Loss: 1.7585
# Epoch:25 | Iter:   60 | Time: 00:00:12 | Train Loss: 1.4888 | Average Loss: 1.7558
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:12 | Train Loss: 1.4642 | Average Loss: 1.7536
# Epoch:26 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.5379 | Average Loss: 1.7507
# Epoch:26 | Iter:   40 | Time: 00:00:12 | Train Loss: 1.5076 | Average Loss: 1.7479
# Epoch:26 | Iter:   60 | Time: 00:00:12 | Train Loss: 1.5477 | Average Loss: 1.7448
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:12 | Train Loss: 1.5561 | Average Loss: 1.7426
# Epoch:27 | Iter:   20 | Time: 00:00:13 | Train Loss: 1.6353 | Average Loss: 1.7394
# Epoch:27 | Iter:   40 | Time: 00:00:13 | Train Loss: 1.6086 | Average Loss: 1.7367
# Epoch:27 | Iter:   60 | Time: 00:00:13 | Train Loss: 1.4438 | Average Loss: 1.7339
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:13 | Train Loss: 1.3831 | Average Loss: 1.7320
# Epoch:28 | Iter:   20 | Time: 00:00:13 | Train Loss: 1.4316 | Average Loss: 1.7291
# Epoch:28 | Iter:   40 | Time: 00:00:13 | Train Loss: 1.5736 | Average Loss: 1.7260
# Epoch:28 | Iter:   60 | Time: 00:00:13 | Train Loss: 1.5561 | Average Loss: 1.7234
# Accuracy: 0.677083 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:13 | Train Loss: 1.3983 | Average Loss: 1.7216
# Epoch:29 | Iter:   20 | Time: 00:00:14 | Train Loss: 1.3587 | Average Loss: 1.7189
# Epoch:29 | Iter:   40 | Time: 00:00:14 | Train Loss: 1.5916 | Average Loss: 1.7161
# Epoch:29 | Iter:   60 | Time: 00:00:14 | Train Loss: 1.4179 | Average Loss: 1.7133
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:14 | Train Loss: 1.0746 | Average Loss: 1.7110
# Epoch:30 | Iter:   20 | Time: 00:00:14 | Train Loss: 1.5619 | Average Loss: 1.7087
# Epoch:30 | Iter:   40 | Time: 00:00:14 | Train Loss: 1.6393 | Average Loss: 1.7060
# Epoch:30 | Iter:   60 | Time: 00:00:14 | Train Loss: 1.4246 | Average Loss: 1.7039
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:14 | Train Loss: 1.3899 | Average Loss: 1.7021
# Epoch:31 | Iter:   20 | Time: 00:00:14 | Train Loss: 1.2693 | Average Loss: 1.6996
# Epoch:31 | Iter:   40 | Time: 00:00:15 | Train Loss: 1.5046 | Average Loss: 1.6974
# Epoch:31 | Iter:   60 | Time: 00:00:15 | Train Loss: 1.3205 | Average Loss: 1.6949
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:15 | Train Loss: 1.3679 | Average Loss: 1.6935
# Epoch:32 | Iter:   20 | Time: 00:00:15 | Train Loss: 1.4232 | Average Loss: 1.6913
# Epoch:32 | Iter:   40 | Time: 00:00:15 | Train Loss: 1.6515 | Average Loss: 1.6894
# Epoch:32 | Iter:   60 | Time: 00:00:15 | Train Loss: 1.4015 | Average Loss: 1.6871
# Accuracy: 0.669271 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:15 | Train Loss: 1.3701 | Average Loss: 1.6854
# Epoch:33 | Iter:   20 | Time: 00:00:15 | Train Loss: 1.5673 | Average Loss: 1.6833
# Epoch:33 | Iter:   40 | Time: 00:00:16 | Train Loss: 1.3005 | Average Loss: 1.6814
# Epoch:33 | Iter:   60 | Time: 00:00:16 | Train Loss: 1.6947 | Average Loss: 1.6796
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:16 | Train Loss: 1.3294 | Average Loss: 1.6779
# Epoch:34 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.3355 | Average Loss: 1.6760
# Epoch:34 | Iter:   40 | Time: 00:00:16 | Train Loss: 1.3244 | Average Loss: 1.6740
# Epoch:34 | Iter:   60 | Time: 00:00:16 | Train Loss: 1.6556 | Average Loss: 1.6716
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:16 | Train Loss: 1.3068 | Average Loss: 1.6699
# Epoch:35 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.2537 | Average Loss: 1.6677
# Epoch:35 | Iter:   40 | Time: 00:00:17 | Train Loss: 1.4507 | Average Loss: 1.6656
# Epoch:35 | Iter:   60 | Time: 00:00:17 | Train Loss: 1.4461 | Average Loss: 1.6632
# Accuracy: 0.666667 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:17 | Train Loss: 1.1820 | Average Loss: 1.6615
# Epoch:36 | Iter:   20 | Time: 00:00:17 | Train Loss: 1.3680 | Average Loss: 1.6594
# Epoch:36 | Iter:   40 | Time: 00:00:17 | Train Loss: 1.3444 | Average Loss: 1.6574
# Epoch:36 | Iter:   60 | Time: 00:00:17 | Train Loss: 1.4343 | Average Loss: 1.6554
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:17 | Train Loss: 1.3014 | Average Loss: 1.6540
# Epoch:37 | Iter:   20 | Time: 00:00:17 | Train Loss: 1.2850 | Average Loss: 1.6518
# Epoch:37 | Iter:   40 | Time: 00:00:18 | Train Loss: 1.3536 | Average Loss: 1.6500
# Epoch:37 | Iter:   60 | Time: 00:00:18 | Train Loss: 1.2755 | Average Loss: 1.6480
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:18 | Train Loss: 1.2761 | Average Loss: 1.6467
# Epoch:38 | Iter:   20 | Time: 00:00:18 | Train Loss: 1.2745 | Average Loss: 1.6446
# Epoch:38 | Iter:   40 | Time: 00:00:18 | Train Loss: 1.4252 | Average Loss: 1.6426
# Epoch:38 | Iter:   60 | Time: 00:00:18 | Train Loss: 1.4283 | Average Loss: 1.6407
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:18 | Train Loss: 1.4026 | Average Loss: 1.6395
# Epoch:39 | Iter:   20 | Time: 00:00:18 | Train Loss: 1.2361 | Average Loss: 1.6377
# Epoch:39 | Iter:   40 | Time: 00:00:19 | Train Loss: 1.2093 | Average Loss: 1.6358
# Epoch:39 | Iter:   60 | Time: 00:00:19 | Train Loss: 1.2972 | Average Loss: 1.6337
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:19 | Train Loss: 1.2811 | Average Loss: 1.6327
# Epoch:40 | Iter:   20 | Time: 00:00:19 | Train Loss: 1.3005 | Average Loss: 1.6309
# Epoch:40 | Iter:   40 | Time: 00:00:19 | Train Loss: 1.3507 | Average Loss: 1.6292
# Epoch:40 | Iter:   60 | Time: 00:00:19 | Train Loss: 1.4529 | Average Loss: 1.6274
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:19 | Train Loss: 1.1213 | Average Loss: 1.6263
# Epoch:41 | Iter:   20 | Time: 00:00:19 | Train Loss: 1.1539 | Average Loss: 1.6246
# Epoch:41 | Iter:   40 | Time: 00:00:20 | Train Loss: 1.2452 | Average Loss: 1.6227
# Epoch:41 | Iter:   60 | Time: 00:00:20 | Train Loss: 1.5638 | Average Loss: 1.6210
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:20 | Train Loss: 1.2614 | Average Loss: 1.6198
# Epoch:42 | Iter:   20 | Time: 00:00:20 | Train Loss: 1.3427 | Average Loss: 1.6179
# Epoch:42 | Iter:   40 | Time: 00:00:20 | Train Loss: 1.5393 | Average Loss: 1.6162
# Epoch:42 | Iter:   60 | Time: 00:00:20 | Train Loss: 1.3005 | Average Loss: 1.6147
# Accuracy: 0.666667 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:20 | Train Loss: 1.1326 | Average Loss: 1.6136
# Epoch:43 | Iter:   20 | Time: 00:00:20 | Train Loss: 1.0793 | Average Loss: 1.6118
# Epoch:43 | Iter:   40 | Time: 00:00:21 | Train Loss: 1.5304 | Average Loss: 1.6101
# Epoch:43 | Iter:   60 | Time: 00:00:21 | Train Loss: 1.6040 | Average Loss: 1.6085
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:21 | Train Loss: 1.4715 | Average Loss: 1.6072
# Epoch:44 | Iter:   20 | Time: 00:00:21 | Train Loss: 1.2876 | Average Loss: 1.6054
# Epoch:44 | Iter:   40 | Time: 00:00:21 | Train Loss: 1.3995 | Average Loss: 1.6039
# Epoch:44 | Iter:   60 | Time: 00:00:21 | Train Loss: 1.3257 | Average Loss: 1.6024
# Accuracy: 0.682292 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:21 | Train Loss: 1.2445 | Average Loss: 1.6014
# Epoch:45 | Iter:   20 | Time: 00:00:21 | Train Loss: 1.1242 | Average Loss: 1.5998
# Epoch:45 | Iter:   40 | Time: 00:00:22 | Train Loss: 1.4118 | Average Loss: 1.5981
# Epoch:45 | Iter:   60 | Time: 00:00:22 | Train Loss: 1.3690 | Average Loss: 1.5967
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:22 | Train Loss: 1.2501 | Average Loss: 1.5958
# Epoch:46 | Iter:   20 | Time: 00:00:22 | Train Loss: 1.4433 | Average Loss: 1.5944
# Epoch:46 | Iter:   40 | Time: 00:00:22 | Train Loss: 1.4975 | Average Loss: 1.5930
# Epoch:46 | Iter:   60 | Time: 00:00:22 | Train Loss: 1.3985 | Average Loss: 1.5918
# Accuracy: 0.669271 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:22 | Train Loss: 1.1968 | Average Loss: 1.5909
# Epoch:47 | Iter:   20 | Time: 00:00:22 | Train Loss: 1.1719 | Average Loss: 1.5893
# Epoch:47 | Iter:   40 | Time: 00:00:23 | Train Loss: 1.2906 | Average Loss: 1.5879
# Epoch:47 | Iter:   60 | Time: 00:00:23 | Train Loss: 1.4601 | Average Loss: 1.5868
# Accuracy: 0.682292 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:23 | Train Loss: 1.2711 | Average Loss: 1.5857
# Epoch:48 | Iter:   20 | Time: 00:00:23 | Train Loss: 1.3313 | Average Loss: 1.5842
# Epoch:48 | Iter:   40 | Time: 00:00:23 | Train Loss: 1.4886 | Average Loss: 1.5829
# Epoch:48 | Iter:   60 | Time: 00:00:23 | Train Loss: 1.4990 | Average Loss: 1.5813
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:23 | Train Loss: 1.4528 | Average Loss: 1.5805
# Epoch:49 | Iter:   20 | Time: 00:00:23 | Train Loss: 1.3539 | Average Loss: 1.5791
# Epoch:49 | Iter:   40 | Time: 00:00:23 | Train Loss: 1.2115 | Average Loss: 1.5778
# Epoch:49 | Iter:   60 | Time: 00:00:24 | Train Loss: 1.5374 | Average Loss: 1.5764
# Accuracy: 0.677083 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:24 | Train Loss: 1.2846 | Average Loss: 1.5756
# Epoch:50 | Iter:   20 | Time: 00:00:24 | Train Loss: 1.4107 | Average Loss: 1.5743
# Epoch:50 | Iter:   40 | Time: 00:00:24 | Train Loss: 1.2505 | Average Loss: 1.5732
# Epoch:50 | Iter:   60 | Time: 00:00:24 | Train Loss: 1.2743 | Average Loss: 1.5719
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:24 | Train Loss: 1.2370 | Average Loss: 1.5710
# Epoch:51 | Iter:   20 | Time: 00:00:24 | Train Loss: 1.2557 | Average Loss: 1.5697
# Epoch:51 | Iter:   40 | Time: 00:00:24 | Train Loss: 1.1386 | Average Loss: 1.5683
# Epoch:51 | Iter:   60 | Time: 00:00:25 | Train Loss: 1.3342 | Average Loss: 1.5671
# Accuracy: 0.684896 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:25 | Train Loss: 1.0891 | Average Loss: 1.5661
# Epoch:52 | Iter:   20 | Time: 00:00:25 | Train Loss: 1.2338 | Average Loss: 1.5648
# Epoch:52 | Iter:   40 | Time: 00:00:25 | Train Loss: 1.3151 | Average Loss: 1.5632
# Epoch:52 | Iter:   60 | Time: 00:00:25 | Train Loss: 1.3675 | Average Loss: 1.5620
# Accuracy: 0.669271 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:25 | Train Loss: 1.2351 | Average Loss: 1.5611
# Epoch:53 | Iter:   20 | Time: 00:00:25 | Train Loss: 1.1402 | Average Loss: 1.5599
# Epoch:53 | Iter:   40 | Time: 00:00:25 | Train Loss: 1.3742 | Average Loss: 1.5589
# Epoch:53 | Iter:   60 | Time: 00:00:26 | Train Loss: 1.3183 | Average Loss: 1.5576
# Accuracy: 0.666667 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:26 | Train Loss: 1.2431 | Average Loss: 1.5568
# Epoch:54 | Iter:   20 | Time: 00:00:26 | Train Loss: 1.2674 | Average Loss: 1.5555
# Epoch:54 | Iter:   40 | Time: 00:00:26 | Train Loss: 1.4071 | Average Loss: 1.5541
# Epoch:54 | Iter:   60 | Time: 00:00:26 | Train Loss: 1.1377 | Average Loss: 1.5528
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:26 | Train Loss: 1.2832 | Average Loss: 1.5520
# Epoch:55 | Iter:   20 | Time: 00:00:26 | Train Loss: 1.5660 | Average Loss: 1.5508
# Epoch:55 | Iter:   40 | Time: 00:00:26 | Train Loss: 1.4360 | Average Loss: 1.5494
# Epoch:55 | Iter:   60 | Time: 00:00:27 | Train Loss: 1.2769 | Average Loss: 1.5480
# Accuracy: 0.682292 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:27 | Train Loss: 1.1430 | Average Loss: 1.5472
# Epoch:56 | Iter:   20 | Time: 00:00:27 | Train Loss: 1.2749 | Average Loss: 1.5461
# Epoch:56 | Iter:   40 | Time: 00:00:27 | Train Loss: 1.3313 | Average Loss: 1.5450
# Epoch:56 | Iter:   60 | Time: 00:00:27 | Train Loss: 1.0364 | Average Loss: 1.5437
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:27 | Train Loss: 1.3338 | Average Loss: 1.5432
# Epoch:57 | Iter:   20 | Time: 00:00:27 | Train Loss: 1.2773 | Average Loss: 1.5419
# Epoch:57 | Iter:   40 | Time: 00:00:27 | Train Loss: 1.2230 | Average Loss: 1.5408
# Epoch:57 | Iter:   60 | Time: 00:00:28 | Train Loss: 1.5261 | Average Loss: 1.5397
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:28 | Train Loss: 1.2460 | Average Loss: 1.5389
# Epoch:58 | Iter:   20 | Time: 00:00:28 | Train Loss: 1.3067 | Average Loss: 1.5377
# Epoch:58 | Iter:   40 | Time: 00:00:28 | Train Loss: 1.3722 | Average Loss: 1.5366
# Epoch:58 | Iter:   60 | Time: 00:00:28 | Train Loss: 1.2098 | Average Loss: 1.5355
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:28 | Train Loss: 1.3122 | Average Loss: 1.5348
# Epoch:59 | Iter:   20 | Time: 00:00:28 | Train Loss: 1.1648 | Average Loss: 1.5338
# Epoch:59 | Iter:   40 | Time: 00:00:29 | Train Loss: 1.4401 | Average Loss: 1.5327
# Epoch:59 | Iter:   60 | Time: 00:00:29 | Train Loss: 1.4750 | Average Loss: 1.5316
# Accuracy: 0.700521 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:29 | Train Loss: 1.2774 | Average Loss: 1.5310
# Epoch:60 | Iter:   20 | Time: 00:00:29 | Train Loss: 1.1993 | Average Loss: 1.5300
# Epoch:60 | Iter:   40 | Time: 00:00:29 | Train Loss: 1.1786 | Average Loss: 1.5289
# Epoch:60 | Iter:   60 | Time: 00:00:29 | Train Loss: 1.2921 | Average Loss: 1.5277
# Accuracy: 0.687500 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 3: Using Leaky Relu and Softmax Actiavtion Functions and adding a Dropout Layer to the architecture of Technique 2
#
# Accuracy on test set: 68.7500 (Maximum accuracy 70.0521 at 59 epoch)
#
# Accuracy increases/decreases: Increases

# %% [markdown]
# ## Problem 2: Fine Tuning a Pre-Trained Deep Network
# Our convolutional network to this point isn't "deep". Fortunately, the representations learned by deep convolutional networks is that they generalize surprisingly well to other recognition tasks.
#
# But how do we use an existing deep network for a new recognition task? Take for instance,  [AlexNet](http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks) network has 1000 units in the final layer corresponding to 1000 ImageNet categories.
#
#
# **Hints**:
# - Many pre-trained models are available in PyTorch at [here](http://pytorch.org/docs/master/torchvision/models.html).
# - For fine-tuning pretrained network using PyTorch, please read this [tutorial](http://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).

# %% [markdown]
# ### Problem 2.1
#
# **Strategy A**: *Fine-tune* an existing network. In this scenario you take an existing network, replace the final layer (or more) with random weights, and train the entire network again with images and ground truth labels for your recognition task. You are effectively treating the pre-trained deep network as a better initialization than the random weights used when training from scratch. When you don't have enough training data to train a complex network from scratch (e.g. with the 16 classes) this is an attractive option. Fine-tuning can work far better than Strategy B of taking the activations directly from an pre-trained CNN. For example, in [this paper](http://www.cc.gatech.edu/~hays/papers/deep_geo.pdf) from CVPR 2015, there wasn't enough data to train a deep network from scratch, but fine tuning led to 4 times higher accuracy than using off-the-shelf networks directly.
#
# (25 points) You are required to implement Strategy A to fine-tune a pre-trained **AlexNet** for this scene classification task. You should be able to achieve accuracy of **0.85** approximately. The minimum accuracy required for this section is **0.75**.
#
# Please provide detailed descriptions of:<br>
# (1) which layers of AlexNet have been replaced<br>
# (2) the architecture of the new layers added including activation methods (same as problem 1)<br>
# (3) the final accuracy on test set <br>

# %%
# reload data with a larger size
img_size = (224, 224)
batch_size = 64 # training sample number per batch 

# load training dataset
trainloader_large = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, 
                                      augment=False, is_color=True, zero_centered=True))
train_num = len(trainloader_large)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_large = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, is_color=True, zero_centered=True))
test_num = len(testloader_large)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
import torchvision.models as models
alexnet =  models.alexnet(pretrained=True)
print("Original AlexNet", alexnet)

alexnet.classifier = nn.Sequential(
    nn.Linear(9216, 1024),
    nn.BatchNorm1d(1024),
    nn.ReLU(),
    nn.Dropout(0.7),
    nn.Linear(1024, 128),
    nn.BatchNorm1d(128),
    nn.ReLU(),
    nn.Dropout(0.7),
    nn.Linear(128, 16)
)
print("Modified Alexnet", alexnet)

#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
train_option = {}
train_option['lr'] = 0.0002
train_option['epoch'] = 30
train_option['loss'] = nn.CrossEntropyLoss
train_option['device'] = 'gpu'

alexnet.train()
 
trainModel(alexnet, trainloader_large, train_option, testloader_large)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
#   0%|          | 0.00/233M [00:00<?, ?B/s]
# Original AlexNet AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )
# Modified Alexnet AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Linear(in_features=9216, out_features=1024, bias=True)
#     (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.7, inplace=False)
#     (4): Linear(in_features=1024, out_features=128, bias=True)
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.7, inplace=False)
#     (8): Linear(in_features=128, out_features=16, bias=True)
#   )
# )
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0547 | Average Loss: 3.0547
# Epoch: 1 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.2246 | Average Loss: 2.5100
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:03 | Train Loss: 2.0013 | Average Loss: 2.2890
# Epoch: 2 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.6966 | Average Loss: 2.0990
# Accuracy: 0.768229 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.5870 | Average Loss: 1.9734
# Epoch: 3 | Iter:   20 | Time: 00:00:08 | Train Loss: 1.4683 | Average Loss: 1.8553
# Accuracy: 0.807292 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:10 | Train Loss: 1.3724 | Average Loss: 1.7676
# Epoch: 4 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.1718 | Average Loss: 1.6849
# Accuracy: 0.841146 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:14 | Train Loss: 1.0889 | Average Loss: 1.6169
# Epoch: 5 | Iter:   20 | Time: 00:00:15 | Train Loss: 1.0233 | Average Loss: 1.5465
# Accuracy: 0.830729 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:17 | Train Loss: 1.0008 | Average Loss: 1.4913
# Epoch: 6 | Iter:   20 | Time: 00:00:19 | Train Loss: 1.0093 | Average Loss: 1.4347
# Accuracy: 0.841146 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.8695 | Average Loss: 1.3869
# Epoch: 7 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.7390 | Average Loss: 1.3363
# Accuracy: 0.846354 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.7243 | Average Loss: 1.2943
# Epoch: 8 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.6336 | Average Loss: 1.2497
# Accuracy: 0.820312 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.6360 | Average Loss: 1.2119
# Epoch: 9 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.4508 | Average Loss: 1.1691
# Accuracy: 0.841146 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.4614 | Average Loss: 1.1361
# Epoch:10 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.5369 | Average Loss: 1.0980
# Accuracy: 0.833333 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.4456 | Average Loss: 1.0680
# Epoch:11 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.4351 | Average Loss: 1.0346
# Accuracy: 0.825521 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.2949 | Average Loss: 1.0069
# Epoch:12 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.3515 | Average Loss: 0.9758
# Accuracy: 0.820312 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:44 | Train Loss: 0.4358 | Average Loss: 0.9511
# Epoch:13 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.2836 | Average Loss: 0.9238
# Accuracy: 0.828125 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:48 | Train Loss: 0.3492 | Average Loss: 0.9013
# Epoch:14 | Iter:   20 | Time: 00:00:49 | Train Loss: 0.2519 | Average Loss: 0.8758
# Accuracy: 0.859375 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:51 | Train Loss: 0.3149 | Average Loss: 0.8556
# Epoch:15 | Iter:   20 | Time: 00:00:53 | Train Loss: 0.2600 | Average Loss: 0.8330
# Accuracy: 0.843750 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:55 | Train Loss: 0.2018 | Average Loss: 0.8139
# Epoch:16 | Iter:   20 | Time: 00:00:57 | Train Loss: 0.2045 | Average Loss: 0.7935
# Accuracy: 0.867188 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:58 | Train Loss: 0.2407 | Average Loss: 0.7773
# Epoch:17 | Iter:   20 | Time: 00:01:00 | Train Loss: 0.2184 | Average Loss: 0.7588
# Accuracy: 0.833333 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:01:02 | Train Loss: 0.2082 | Average Loss: 0.7436
# Epoch:18 | Iter:   20 | Time: 00:01:04 | Train Loss: 0.1627 | Average Loss: 0.7262
# Accuracy: 0.817708 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:01:05 | Train Loss: 0.2920 | Average Loss: 0.7127
# Epoch:19 | Iter:   20 | Time: 00:01:07 | Train Loss: 0.1767 | Average Loss: 0.6969
# Accuracy: 0.830729 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:01:09 | Train Loss: 0.1528 | Average Loss: 0.6842
# Epoch:20 | Iter:   20 | Time: 00:01:11 | Train Loss: 0.1465 | Average Loss: 0.6693
# Accuracy: 0.833333 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:01:12 | Train Loss: 0.1327 | Average Loss: 0.6574
# Epoch:21 | Iter:   20 | Time: 00:01:14 | Train Loss: 0.1456 | Average Loss: 0.6439
# Accuracy: 0.851562 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:01:16 | Train Loss: 0.1536 | Average Loss: 0.6330
# Epoch:22 | Iter:   20 | Time: 00:01:18 | Train Loss: 0.1402 | Average Loss: 0.6205
# Accuracy: 0.812500 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:01:20 | Train Loss: 0.1569 | Average Loss: 0.6103
# Epoch:23 | Iter:   20 | Time: 00:01:22 | Train Loss: 0.1599 | Average Loss: 0.5987
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:01:23 | Train Loss: 0.1410 | Average Loss: 0.5895
# Epoch:24 | Iter:   20 | Time: 00:01:25 | Train Loss: 0.1126 | Average Loss: 0.5785
# Accuracy: 0.854167 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:01:28 | Train Loss: 0.1116 | Average Loss: 0.5697
# Epoch:25 | Iter:   20 | Time: 00:01:30 | Train Loss: 0.1462 | Average Loss: 0.5595
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:01:32 | Train Loss: 0.1361 | Average Loss: 0.5513
# Epoch:26 | Iter:   20 | Time: 00:01:33 | Train Loss: 0.1085 | Average Loss: 0.5417
# Accuracy: 0.848958 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:01:35 | Train Loss: 0.1089 | Average Loss: 0.5340
# Epoch:27 | Iter:   20 | Time: 00:01:37 | Train Loss: 0.1168 | Average Loss: 0.5250
# Accuracy: 0.851562 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:01:39 | Train Loss: 0.0678 | Average Loss: 0.5179
# Epoch:28 | Iter:   20 | Time: 00:01:40 | Train Loss: 0.0840 | Average Loss: 0.5095
# Accuracy: 0.838542 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:01:42 | Train Loss: 0.1126 | Average Loss: 0.5026
# Epoch:29 | Iter:   20 | Time: 00:01:44 | Train Loss: 0.1181 | Average Loss: 0.4948
# Accuracy: 0.848958 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:01:46 | Train Loss: 0.0619 | Average Loss: 0.4883
# Epoch:30 | Iter:   20 | Time: 00:01:47 | Train Loss: 0.0567 | Average Loss: 0.4807
# Accuracy: 0.846354 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# (1) which layers of AlexNet have been replaced
#
# The Feature Layer is kept the same, the classifier layer is replaced with Linear Layers (Fully Connected dense layers)
#
#
# (2) the architecture of the new layers added including activation methods (same as problem 1)
#
# Data augmentation: The augment parameter in the load_dataset function is set to False. I have not flipped the image horizontally to create a mirror image.
#
# Data normalization: I calculated the mean and subtracted with the image data to make them zero centerd.
#
# Features Layers : Kept the same
#
# Classifier Layers 1: Features Module contains Conv2d and Pooling layers. (Inherted from the AlexNet)
#
# Classifier Layers 2: avgpool Module contains Adaptive average pooling layer. (Inherited from the AlexNet)
#
# Classifier Layers 3: Custom Classifier Module replaces the existing one from AlexNet.
#
# a) Fully Connected Dense Layer (Linear Layer) (9216 input channels and 1024 output channels)
#
# b) Batch Normalisation Layer (1024 features)
#
# c) ReLU Activation Function Layer
#
# d) Dropout Layer (0.7)
#
# e) Fully Connected Dense Layer (Linear Layer) (1024 input channels and 128 output channels)
#
# f) Batch Normalisation Layer (128 features)
#
# g) ReLU Activation Function Layer
#
# h) Dropout Layer (0.7)
#
# i) Fully Connected Dense Layer (Linear Layer) (128 input channels and 16 output channels)
#
# ...
#
# (3) the final accuracy on test set
#
# Accuracy on test set: 84.6354 (Maximum Accuracy 85.6771 at 25 epoch)

# %% [markdown]
# ### Problem 2.2
# **Strategy B**: One could use those 1000 activations as a feature in place of a hand crafted feature such as a bag-of-features representation. You would train a classifier (typically a linear SVM) in that 1000 dimensional feature space. However, those activations are clearly very object specific and may not generalize well to new recognition tasks. It is generally better to use the activations in slightly earlier layers of the network, e.g. the 4096 activations in the last 2nd fully-connected layer. You can often get away with sub-sampling those 4096 activations considerably, e.g. taking only the first 1000 activations.
#
# (25 points) Implement Strategy B where you use the activations of the pre-trained **AlexNet** as features to train **one-vs-all SVMs** for your scene classification task. Report the final accuracy on test set. You should be able to achieve accuracy of **0.80** approximately. The minimum accuracy required for this section is **0.70**.

# %%
#--------------------------------------------------
#       Get Features from AlexNet
#--------------------------------------------------
new_alexnet = torchvision.models.alexnet(pretrained=True)
new_alexnet.eval()

def features_extract(net, data):
  features = []
  label = []
  for x, y in data:
        x_batch = x.float()
        y_batch = y.float()
        ops = net.features(x_batch)
        features.append(ops.detach().cpu().numpy().flatten().reshape(len(x), 256 * 6 * 6))
        label += list(y_batch.detach().cpu().numpy())
  label = np.array(label)
  features = np.vstack(features)
  return features, label

train_feat, train_label = features_extract(new_alexnet, trainloader_large)
test_feat, test_label = features_extract(new_alexnet, testloader_large)

# %%
#--------------------------------------------------
#       Train and Evaluate SVM
#--------------------------------------------------
from sklearn import svm 

svm = svm.SVC(kernel='rbf')
svm.fit(train_feat, train_label)
label_pred_test = svm.predict(test_feat)
test_accuracy = sum(np.array(label_pred_test) == test_label) / float(len(test_label))

print(f"Accuracy on test dataset: {test_accuracy:.6f} ")
# Out:
# Accuracy on test dataset: 0.838542

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: 83.8542

# %% [markdown]
# ### Problem 2.3 (Bonus)
#
# (Bonus: 10 points) Bonus will be given to those who fine-tune the [ResNet network](https://pytorch.org/docs/stable/_modules/torchvision/models/resnet.html) [(paper)](https://arxiv.org/abs/1512.03385) and compare performance with AlexNet. Explain why ResNet performed better or worse. You are **required** to use **resnet50** model. You should be able to achieve accuracy of **0.99** approximately. The minimum accuracy required for this section is **0.85**.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
resnet = torchvision.models.resnet50(pretrained=True)
##########--WRITE YOUR CODE HERE--##########
 
resnet.classifier = nn.Sequential(
    nn.Linear(9216, 1024),
    nn.BatchNorm1d(1024),
    nn.ReLU(),
    nn.Dropout(0.7),
    nn.Linear(1024, 128),
    nn.BatchNorm1d(128),
    nn.ReLU(),
    nn.Dropout(0.7),
    nn.Linear(128, 16)
)

#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
train_option = {}
train_option['lr'] = 0.0002
train_option['epoch'] = 10
train_option['loss'] = nn.CrossEntropyLoss
train_option['device'] = 'gpu'
resnet.train()

trainModel(resnet, trainloader_large, train_option, testloader_large)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 9.7969 | Average Loss: 9.7969
# Epoch: 1 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.5854 | Average Loss: 2.2546
# Accuracy: 0.812500 | Time: 00:00:01
# Epoch: 2 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.3523 | Average Loss: 1.4654
# Epoch: 2 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0635 | Average Loss: 1.0181
# Accuracy: 0.877604 | Time: 00:00:01
# Epoch: 3 | Iter:    0 | Time: 00:00:56 | Train Loss: 0.1077 | Average Loss: 0.8069
# Epoch: 3 | Iter:   20 | Time: 00:01:11 | Train Loss: 0.0765 | Average Loss: 0.6437
# Accuracy: 0.882812 | Time: 00:00:01
# Epoch: 4 | Iter:    0 | Time: 00:01:24 | Train Loss: 0.0191 | Average Loss: 0.5500
# Epoch: 4 | Iter:   20 | Time: 00:01:38 | Train Loss: 0.0134 | Average Loss: 0.4691
# Accuracy: 0.901042 | Time: 00:00:01
# Epoch: 5 | Iter:    0 | Time: 00:01:52 | Train Loss: 0.0019 | Average Loss: 0.4170
# Epoch: 5 | Iter:   20 | Time: 00:02:06 | Train Loss: 0.0043 | Average Loss: 0.3687
# Accuracy: 0.914062 | Time: 00:00:01
# Epoch: 6 | Iter:    0 | Time: 00:02:20 | Train Loss: 0.1111 | Average Loss: 0.3362
# Epoch: 6 | Iter:   20 | Time: 00:02:34 | Train Loss: 0.0017 | Average Loss: 0.3043
# Accuracy: 0.919271 | Time: 00:00:01
# Epoch: 7 | Iter:    0 | Time: 00:02:48 | Train Loss: 0.0013 | Average Loss: 0.2814
# Epoch: 7 | Iter:   20 | Time: 00:03:02 | Train Loss: 0.0020 | Average Loss: 0.2583
# Accuracy: 0.921875 | Time: 00:00:01
# Epoch: 8 | Iter:    0 | Time: 00:03:15 | Train Loss: 0.0006 | Average Loss: 0.2415
# Epoch: 8 | Iter:   20 | Time: 00:03:30 | Train Loss: 0.0007 | Average Loss: 0.2243
# Accuracy: 0.924479 | Time: 00:00:01
# Epoch: 9 | Iter:    0 | Time: 00:03:43 | Train Loss: 0.0004 | Average Loss: 0.2115
# Epoch: 9 | Iter:   20 | Time: 00:03:57 | Train Loss: 0.0005 | Average Loss: 0.1982
# Accuracy: 0.921875 | Time: 00:00:01
# Epoch:10 | Iter:    0 | Time: 00:04:11 | Train Loss: 0.0003 | Average Loss: 0.1881
# Epoch:10 | Iter:   20 | Time: 00:04:25 | Train Loss: 0.0004 | Average Loss: 0.1775
# Accuracy: 0.924479 | Time: 00:00:01

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: 92.4479
#
# (Increasing epochs would increase the accuracy further)
#
# Even with fewer epochs, ResNet (0.92 with 10 epochs) outperforms alexnet (0.84 with 30 epochs). Even though both use a comparable amount of parameters, Resnet requires substantially more time to train the data because of the complicated computations.

# %% [markdown]
# ## Submission guidelines
# ---
# We will grade your homework based on your submitted notebook file. We will check the notebook for both results and code. Please make sure you run your code and print out the results in the notebook before submitting (we expect to see the results before running your code by ourselves.)
#
# You submit your homework by first creating a ***google shared link*** of a folder for your homework (described below), and put that link into the ***text submission section*** of your homework submission on Blackboard. ([How to submit your link?](https://drive.google.com/file/d/16-FlPSiu5n-pRezLfcbAvgYxXtGtrs16))
#
# To generate the ***google shared link***, first create a folder named ***Surname_Givenname_SBUID_hw**** in your Google Drive with your CS account (or your SBU account if you don't have a CS account). The structure of the files in the folder should be exactly the same as the one you downloaded. For instance in this homework:
#
# ```
# Surname_Givenname_SBUID_hw4
#         |---CSE527-22F-HW4.ipynb
# ```
# Note that this folder should be in your Google Drive with your account.
#
# Then right click this folder, click ***Get shareable link***, in the People textfield, enter the TAs' email: ***haoyuwu@cs.stonybrook.edu*** and ***vhnguyen@cs.stonybrook.edu***. Make sure that the TAs who have the link **can edit**, ***not just*** **can view**, and also **uncheck** the **Notify people** box. ([How to share link?](https://drive.google.com/file/d/17R6j6yE8_8vXioOB3nNvbEPzxcI-rr_H) )
#
# ***IMPORTANT: Please do not make any modification to the folder and its files after the submission deadline***. (All modifications can be seen by the TAs via the revision history.) Note that in google colab, we will only grade the version of the code right before the timestamp of the submission made in blackboard.
#
# The input and output paths are predefined and **DO NOT** change them, (we assume that 'Surname_Givenname_SBUID_hw1' is your working directory, and all the paths are relative to this directory).  The image read and write functions are already written for you. All you need to do is to fill in the blanks as indicated to generate proper outputs.
#
#
# -- DO NOT change the folder structure, please just fill in the blanks. <br>
#
# You are encouraged to post and answer questions on Piazza. Based on the amount of email that we have received in past years, there might be delays in replying to personal emails. Please ask questions on Piazza and send emails only for personal issues.
#
# If you alter the folder structures, the grading of your homework will be significantly delayed and possibly penalized.
#
# Be aware that your code will undergo plagiarism check both vertically and horizontally. Please do your own work.
#
# Late submission penalty: <br>
# There will be a 10% penalty per day for late submission. However, you will have 4 days throughout the whole semester to submit late without penalty. Note that the grace period is calculated by days instead of hours. If you submit the homework one minute after the deadline, one late day will be counted. Likewise, if you submit one minute after the deadline, the 10% penaly will be imposed if not using the grace period.

# %% [markdown]
# <!--Write your report here in markdown or html-->
